# %%
# ML Models---->

# (1). Supervised ML Models---> In this ,we will train our labelled data
#     (a). Descrete----> LogistcRegression, Desiniontreeclassifier,RandomfForestClassifier, naive bayes

#      (b).Continous---> LinerRegression,D.T.regressor

# (2).UnSupervised ML Models---> in this we will train out unlabelled data.

# Kmeans ,PCA,Apriori

# %%
# (1). Supervised ML models---->

# (a).LinerRegression ===>

# %%
### WRKFLOW ----->
# Data Ingestion ----> Data Cleaning and Preprocessing ---->Select ML Models based on

# target column- ---> Model training ----> Model prediction ---> Model Evaluation

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\HARSHITA\\Downloads\\Data_sets\\insurance - insurance.csv")
df.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(columns=['charges'])
y=df['charges']

# %%
# Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
x['sex']=lb.fit_transform(x['sex'])
x['smoker']=lb.fit_transform(x['smoker'])
x['region']=lb.fit_transform(x['region'])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7833463107364539

# %%
df=pd.read_csv("C:\\Users\\HARSHITA\\Downloads\\Data_sets\\Churn_Modelling - Churn_Modelling.csv")
df.head(2)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.00              1          1               1
# 1       1  83807.86              1          0               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0

# %%
x=df.drop(columns=['EstimatedSalary'])
y=df['EstimatedSalary']

# %%
# Encoding

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
x['Surname']=lb.fit_transform(x['Surname'])
x['Geography']=lb.fit_transform(x['Geography'])
x['Gender']=lb.fit_transform(x['Gender'])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_pred,y_test)
# Out:
# -464.6638500409118

# %%
# form-------> entry---> database ----> fetch jupyter -----> ml model

# %%
df=pd.read_csv("C:\\Users\\HARSHITA\\Downloads\\Data_sets\\housing.csv")
df.head(2)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
#
#    Avg. Area Number of Bedrooms  Area Population        Price  \
# 0                          4.09      23086.80050  1059033.558
# 1                          3.09      40173.07217  1505890.915
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...

# %%
df.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['Price'],df['Avg. Area Income'])
plt.xlabel('PRICE')
plt.ylabel('Area Income')
# Out:
# Text(0, 0.5, 'Area Income')

# %%
# Slightly Linear Graph

# %%
x=df.drop(columns=['Price'])
y=df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
# Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
x['Address']=lb.fit_transform(x['Address'])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9179817232331305
