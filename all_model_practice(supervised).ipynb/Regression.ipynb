# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn import svm
from sklearn.metrics import accuracy_score,classification_report
from sklearn.metrics import r2_score
from xgboost import XGBRegressor

# %%
df=pd.read_csv("C:\\Users\\HARSHITA\\OneDrive\\Data_sets\\insurance - insurance.csv")
df.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
x=df.drop(columns=['charges'])
y=df['charges']

# %%
le=LabelEncoder()

# %%
x['sex']=le.fit_transform(x['sex'])
x['smoker']=le.fit_transform(x['smoker'])
x['region']=le.fit_transform(x['region'])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
sc=StandardScaler()
x_train_sc=sc.fit_transform(x_train)
x_test_sc=sc.fit_transform(x_test)

# %% [markdown]
# **LINEAR REGRESSION**

# %%
# lr=LinearRegression()
# print(lr.fit(x_train_sc,y_train))
# y_pred=lr.predict(x_test_sc)
# score=r2_score(y_test,y_pred)
# print(score)
# Out:
# LinearRegression()
# 0.7833237659369185

# %% [markdown]
# **DecisionTreeRegressor**

# %%
# dt=DecisionTreeRegressor()
# dt.fit(x_train_sc,y_train)
# y_pred=dt.predict(x_test_sc)
# score=r2_score(y_test,y_pred)
# print(score)
# Out:
# 0.7618538586061697

# %% [markdown]
# **RandomForestRegressor**

# %%
# rf=RandomForestRegressor()
# rf.fit(x_train_sc,y_train)
# y_pred=rf.predict(x_test_sc)
# score=r2_score(y_test,y_pred)
# print(score)
# Out:
# 0.865563559053219

# %% [markdown]
# **KNN**

# %%
# knn=KNeighborsRegressor(n_neighbors=3)
# knn.fit(x_train_sc,y_train)
# y_pred=knn.predict(x_test_sc)
# score=r2_score(y_test,y_pred)
# print(score)
# Out:
# 0.8024585146087778

# %% [markdown]
# **SupportVectorRegressor**

# %%
# linear_svr=svm.SVR(kernel='linear')
# linear_svr.fit(x_train_sc,y_train)
# y_pred=linear_svr.predict(x_test_sc)
# score=r2_score(y_test,y_pred)
# print(score)
# Out:
# 0.021476337312151594

# %%
# poly_svr=svm.SVR(kernel='poly',degree=3)
# poly_svr.fit(x_train_sc,y_train)
# poly_prediction=poly_svr.predict(x_test_sc)
# poly_score=r2_score(y_test,poly_prediction)
# print(poly_score)
# Out:
# -0.06295816095734863

# %% [markdown]
# **XGBOOST**

# %%
# xgb=XGBRegressor()
# xgb.fit(x_train_sc,y_train)
# y_pred=xgb.predict(x_test_sc)
# print("R2 Score:",r2_score(y_test,y_pred))
# Out:
# R2 Score: 0.8362115604013031
