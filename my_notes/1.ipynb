# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import (
    StandardScaler,
    MinMaxScaler,
    OneHotEncoder,
    OrdinalEncoder,
    LabelEncoder
)
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
df=pd.read_csv("C:\\Users\\HARSHITA\\Downloads\\ecommerce_customer_churn_dataset - ecommerce_customer_churn_dataset.csv")
df.head(4)
# Out:
#     Age  Gender Country        City  Membership_Years  Login_Frequency  \
# 0  43.0    Male  France   Marseille               2.9               14
# 1  36.0    Male      UK  Manchester               1.6               15
# 2  45.0  Female  Canada   Vancouver               2.9               10
# 3  56.0  Female     USA    New York               2.6               10
#
#    Session_Duration_Avg  Pages_Per_Session  Cart_Abandonment_Rate  \
# 0                  27.4                6.0                   50.6
# 1                  42.7               10.3                   37.7
# 2                  24.8                1.6                   70.9
# 3                  38.4               14.8                   41.7
#
#    Wishlist_Items  ...  Email_Open_Rate  Customer_Service_Calls  \
# 0             3.0  ...             17.9                     9.0
# 1             1.0  ...             42.8                     7.0
# 2             1.0  ...              0.0                     4.0
# ...

# %% [markdown]
# ### 1️⃣ STEP 1 -----> HANDLING MISSING VALUES

# %%
df.isnull().mean()
# Out:
# Age                              0.04990
# Gender                           0.00000
# Country                          0.00000
# City                             0.00000
# Membership_Years                 0.00000
# Login_Frequency                  0.00000
# Session_Duration_Avg             0.06798
# Pages_Per_Session                0.06000
# Cart_Abandonment_Rate            0.00000
# Wishlist_Items                   0.08000
# Total_Purchases                  0.00000
# Average_Order_Value              0.00000
# Days_Since_Last_Purchase         0.06000
# Discount_Usage_Rate              0.07000
# Returns_Rate                     0.08982
# Email_Open_Rate                  0.05056
# Customer_Service_Calls           0.00336
# Product_Reviews_Written          0.07000
# Social_Media_Engagement_Score    0.12000
# Mobile_App_Usage                 0.10000
# Payment_Method_Diversity         0.05000
# Lifetime_Value                   0.00000
# Credit_Balance                   0.11000
# ...

# %%
cols=[val for val in df.columns if df[val].isnull().mean()<0.25 and df[val].isnull().mean()>0]
cols
# Out:
# ['Age',
#  'Session_Duration_Avg',
#  'Pages_Per_Session',
#  'Wishlist_Items',
#  'Days_Since_Last_Purchase',
#  'Discount_Usage_Rate',
#  'Returns_Rate',
#  'Email_Open_Rate',
#  'Customer_Service_Calls',
#  'Product_Reviews_Written',
#  'Social_Media_Engagement_Score',
#  'Mobile_App_Usage',
#  'Payment_Method_Diversity',
#  'Credit_Balance']
