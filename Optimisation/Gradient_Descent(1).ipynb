# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X,y=make_regression(n_samples=4,n_features=1,n_informative=1,n_targets=1,noise=80,random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
LinearRegression(copy_X=True,n_jobs=None,fit_intercept=True)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# np.float64(26.15963284313262)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red')

# %%
# Lets appply G.D. assuming slope is
#  constant (m)=78.35
#lets assume intercept
# b=0

# %%
y_pred=((78.35 * X)+0).reshape(4)
y_pred
# Out:
# array([-55.81580837,  35.39949674,  -3.48681619,  59.05759577])

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')

plt.scatter(X,y)
plt.plot(X,y_pred,color='green', label='b=0')

# %%
m=78.35
b=0
Loss_slope=-2-np.sum(y-m*X.ravel()-b)
Loss_slope
# Out:
# np.float64(-106.63881704104608)

# %% [markdown]
# 1.

# %%
lr=0.1
step_size=Loss_slope*lr         # lr*dl/db
step_size
# Out:
# np.float64(-10.66388170410461)

# %%
# new b
b=b-step_size            # b_new=b_old-lr*dl/db
b
# Out:
# np.float64(10.66388170410461)

# %% [markdown]
# 2.

# %%
y_pred_1= ((78.35 * X) + 10.6638817).reshape(4)
y_pred_1
# Out:
# array([-45.15192667,  46.06337844,   7.17706551,  69.72147747])

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')

plt.scatter(X,y)
plt.plot(X,y_pred,color='green', label='b=0')

plt.scatter(X,y)
plt.plot(X,y_pred_1,color='blue', label='b=0')

# %%
m=78.35
b=10.6638817
Loss_slope=-2-np.sum(y-m*X.ravel()-b)
Loss_slope
# Out:
# np.float64(-63.983290241046085)

# %%
lr=0.1
step_size=Loss_slope*lr         # lr*dl/db
step_size
# Out:
# np.float64(-6.3983290241046085)

# %%
b=b-step_size            # b_new=b_old-lr*dl/db
b
# Out:
# np.float64(17.06221072410461)

# %% [markdown]
# ##### just like that calculate y untill we reach to red line exact value of b we got
# ##### b=26.1596
