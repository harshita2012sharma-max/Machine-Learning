# %% [markdown]
# ## columns transformer

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset('tips')
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
from sklearn.model_selection import train_test_split

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df_1=df[['total_bill','tip']]
df_1.head(2)
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66

# %%
# df=df.drop(columns=['total_bill','tip'])

# %%
x=df.drop(columns=['size'])
y=df['size']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x.shape
# Out:
# (244, 6)

# %%
x_train.head(4)
# Out:
#      total_bill   tip   sex smoker  day    time
# 228       13.28  2.72  Male     No  Sat  Dinner
# 208       24.27  2.03  Male    Yes  Sat  Dinner
# 96        27.28  4.00  Male    Yes  Fri  Dinner
# 167       31.71  4.50  Male     No  Sun  Dinner

# %%
x_train.shape
# Out:
# (195, 6)

# %%
oe=OrdinalEncoder(categories=[['Male','Female'],['No','Yes'],['Sun', 'Sat', 'Thur', 'Fri'],['Dinner', 'Lunch']])

# %%
x_train_encoded=oe.fit_transform(x_train[['sex','smoker','day','time']])

# %%
x_train_encoded.shape
# Out:
# (195, 4)

# %%
x_train_total_bill=x_train.drop(columns={'tip','sex','smoker','day','time'}).values
x_train_total_bill.shape
# Out:
# (195, 1)

# %%
x_train_tip=x_train.drop(columns={'total_bill','sex','smoker','day','time',}).values
x_train_tip.shape
# Out:
# (195, 1)

# %%
x_train_transformer=np.concatenate((x_train_encoded,x_train_tip,x_train_total_bill),axis=1)
x_train_transformer.shape
# Out:
# (195, 6)

# %% [markdown]
# ## column TRansformer

# %%
from sklearn.compose import ColumnTransformer

# %%
transformer=ColumnTransformer(transformers=[
    ('tnf1',OrdinalEncoder(categories=[['Male','Female'],['No','Yes'],['Sun', 'Sat', 'Thur', 'Fri'],
    ['Dinner', 'Lunch']]),['sex','smoker','day','time'])],
    remainder='passthrough'
)

# %%
transformed_df=transformer.fit_transform(x_train)

# %%
transformed_df.shape
# Out:
# (195, 6)

# %% [markdown]
# # pipeline

# %%
df=pd.read_csv("C:\\Users\\HARSHITA\\Downloads\\Data_sets\\credit_scoring - credit_scoring.csv")
df.head(2)
# Out:
#    Age Gender Marital Status Education Level Employment Status  \
# 0   60   Male        Married          Master          Employed
# 1   25   Male        Married     High School        Unemployed
#
#    Credit Utilization Ratio  Payment History  Number of Credit Accounts  \
# 0                      0.22             2685                          2
# 1                      0.20             2371                          9
#
#    Loan Amount  Interest Rate  Loan Term   Type of Loan
# 0      4675000           2.65         48  Personal Loan
# 1      3619000           5.19         60      Auto Loan

# %%
df.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# Marital Status               0
# Education Level              0
# Employment Status            0
# Credit Utilization Ratio     0
# Payment History              0
# Number of Credit Accounts    0
# Loan Amount                  0
# Interest Rate                0
# Loan Term                    0
# Type of Loan                 0
# dtype: int64

# %%
x=df.drop(columns=['Type of Loan'])
y=df['Type of Loan']

# %%
numerical_col=x.select_dtypes(exclude=['object']).columns

# %%
categorical_col=x.select_dtypes(include=['object']).columns
categorical_col
# Out:
# Index(['Gender', 'Marital Status', 'Education Level', 'Employment Status'], dtype='object')

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
categoric_pipeline=Pipeline(steps=[
    ('onehot',OneHotEncoder(handle_unknown='ignore'))
])

# %%
# combine transformer
preprocessor=ColumnTransformer(transformers=[
    ('cat',categoric_pipeline,categorical_col)
],remainder='passthrough')

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('classifier',RandomForestClassifier())
])

# %%
rf.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   Index(['Gender', 'Marital Status', 'Education Level', 'Employment Status'], dtype='object'))])),
#                 ('classifier', RandomForestClassifier())])

# %%
y_pred=rf.predict(x_test)
y_pred
# Out:
# array(['Auto Loan', 'Auto Loan', 'Auto Loan', 'Auto Loan', 'Home Loan',
#        'Personal Loan', 'Auto Loan', 'Personal Loan', 'Auto Loan',
#        'Home Loan', 'Home Loan', 'Personal Loan', 'Home Loan',
#        'Auto Loan', 'Home Loan', 'Personal Loan', 'Home Loan',
#        'Home Loan', 'Personal Loan', 'Home Loan', 'Auto Loan',
#        'Auto Loan', 'Auto Loan', 'Personal Loan', 'Home Loan',
#        'Home Loan', 'Home Loan', 'Home Loan', 'Personal Loan',
#        'Home Loan', 'Personal Loan', 'Personal Loan', 'Auto Loan',
#        'Auto Loan', 'Auto Loan', 'Personal Loan', 'Home Loan',
#        'Personal Loan', 'Personal Loan', 'Personal Loan', 'Auto Loan',
#        'Home Loan', 'Auto Loan', 'Home Loan', 'Home Loan',
#        'Personal Loan', 'Home Loan', 'Personal Loan', 'Auto Loan',
#        'Home Loan', 'Personal Loan', 'Personal Loan', 'Personal Loan',
#        'Home Loan', 'Auto Loan', 'Home Loan', 'Personal Loan',
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.33

# %%
trimming----->
new_df=df[df['columns_name']<upper_limit]

# %%
plt.figure(figsize=(15,7))

plt.subplot(222)
sns.boxplot(x=df[])

plt.subplot(224)
sns.bpxplot(x=df[])
