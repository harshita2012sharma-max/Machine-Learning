# %% [markdown]
# # Column Transformer

# %% [markdown]
# #### (1). It is used to apply  preprocessing or different technique on a data set in one single process.
# #### (2). It is more readable and make the code more easier and faster.

# %%
# doing preprocessing without column transformer

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %%
df=pd.read_csv("C:\\Users\\HARSHITA\\Downloads\\Data_sets\\world_alcohol.csv")
df.head(3)
# Out:
#    Year       WHO region       Country Beverage Types  Display Value
# 0  1986  Western Pacific      Viet Nam           Wine           0.00
# 1  1986         Americas       Uruguay          Other           0.50
# 2  1985           Africa  Cte d'Ivoire           Wine           1.62

# %%
df['Display Value'] = pd.to_numeric(df['Display Value'], errors='coerce')

# %%
df.isnull().sum()
# Out:
# Year              0
# WHO region        0
# Country           0
# Beverage Types    0
# Display Value     5
# dtype: int64

# %%
df.shape
# Out:
# (100, 5)

# %%
x=df.drop(columns=['Year'])
y=df['Year']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (80, 4)

# %%
x_test.shape
# Out:
# (20, 4)

# %%
# Manually Encoding and handling missing value

# %%
si=SimpleImputer(strategy='mean')
x_train_display=si.fit_transform(x_train[['Display Value']])

x_test_display=si.transform(x_test[['Display Value']])

# %%
x_train.isnull().sum()
# Out:
# WHO region        0
# Country           0
# Beverage Types    0
# Display Value     3
# dtype: int64

# %%
# Encoding

# %%
x_train_encoded = pd.get_dummies(
    x_train,
    columns=['WHO region', 'Country', 'Beverage Types'],
    drop_first=True
)

x_test_encoded = pd.get_dummies(
    x_test,
    columns=['WHO region', 'Country', 'Beverage Types'],
    drop_first=True
)

# %%
x_train_encoded.shape
# Out:
# (80, 75)
