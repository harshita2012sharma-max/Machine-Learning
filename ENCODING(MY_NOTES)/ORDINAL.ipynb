# %% [markdown]
# # Ordinal Encoding

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\HARSHITA\\Downloads\\Data_sets\\covid_toy - covid_toy.csv")
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
x=df.drop(columns=['has_covid'])
z=
y=df["has_covid"]

# %% [markdown]
# ###### Here we will apply ordinal encoding on x(input data) and in this input data also we will apply on ORDINAL CATEGORICAL DATA
# ###### i.e. cough
# ###### nominal data are----> gender,city
#
# ###### LABLE ENCODING on ---. has_covid

# %%
s=df.loc[:,['cough']]

# %%
s.head()
# Out:
#   cough
# 0  Mild
# 1  Mild
# 2  Mild
# 3  Mild
# 4  Mild

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df.loc[:,['cough']],y,test_size=0.2,random_state=42)

# %%
x_train.head()
# Out:
#    cough
# 55  Mild
# 88  Mild
# 26  Mild
# 42  Mild
# 69  Mild

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe=OrdinalEncoder(categories=[['Mild','Strong']])

# %%
x_train_oe=oe.fit_transform(x_train)

# %%
#x_train_oe

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
y_train
# Out:
# 55    Yes
# 88     No
# 26    Yes
# 42    Yes
# 69     No
#      ...
# 60    Yes
# 71     No
# 14     No
# 92     No
# 51    Yes
# Name: has_covid, Length: 80, dtype: object

# %%
y_train_lb=lb.fit_transform(y_train)

# %% [markdown]
# #### gender and city ----> with OneHot Encoding

# %% [markdown]
# ----> convert x_train into data frame
# ----> convert y_train into dataframe
# ----> merge all data frames

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df=df.loc[:,['age','gender','fever']]

# %%
df.head()
# Out:
#    age  gender  fever
# 0   60    Male  103.0
# 1   27    Male  100.0
# 2   42    Male  101.0
# 3   31  Female   98.0
# 4   65  Female  101.0

# %%
x_train_df=pd.DataFrame(x_train_oe,columns=x_train.columns)

# %%
y_train_df=pd.DataFrame(y_train_lb,columns=y_train.columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16964\2899208221.py in ?()
# ----> 1 y_train_df=pd.DataFrame(y_train_lb,columns=y_train.columns)
#
# c:\Users\HARSHITA\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'
