# %% [markdown]
# **COLUMN TRANSFORMER**

# %% [markdown]
# first we will encode the data set normally than with column tranformer

# %%
import numpy as np
import pandas as pd

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
df=pd.read_csv("/content/covid_toy - covid_toy.csv")
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop(columns=['has_covid']),df['has_covid'],test_size=0.2)

# %%
x_train
# Out:
#     age  gender  fever cough       city
# 0    60    Male  103.0  Mild    Kolkata
# 54   60  Female   99.0  Mild     Mumbai
# 21   73    Male   98.0  Mild  Bangalore
# 67   65    Male   99.0  Mild  Bangalore
# 76   80    Male  100.0  Mild  Bangalore
# ..  ...     ...    ...   ...        ...
# 49   44    Male  104.0  Mild     Mumbai
# 72   83  Female  101.0  Mild    Kolkata
# 3    31  Female   98.0  Mild    Kolkata
# 66   51    Male  104.0  Mild    Kolkata
# 75    5    Male  102.0  Mild    Kolkata
#
# [80 rows x 5 columns]

# %% [markdown]
# # Manually type output

# %%
#adding simple imputer to fever column
si=SimpleImputer(strategy="mean")
x_train_fever=si.fit_transform(x_train[['fever']])
# also the test data
x_test_fever=si.fit_transform(x_test[['fever']])
x_train_fever.shape
# Out:
# (80, 1)

# %%
# Ordinal Encoding---->Cough

oe=OrdinalEncoder(categories=[['Mild','Strong']])
x_train_cough=oe.fit_transform(x_train[['cough']])

# also the test data
x_test_cough=oe.fit_transform(x_test[['cough']])
x_train_cough.shape
# Out:
# (80, 1)

# %%
# OneHotEncoder---> Gender,City
ohe=OneHotEncoder(drop='first',sparse_output=False)
x_train_gender_city=ohe.fit_transform(x_train[['gender','city']])

# also test data
x_test_gender_city=ohe.fit_transform(x_test[['gender','city']])

x_train_gender_city.shape
# Out:
# (80, 4)

# %%
# Extracting Age
x_train_age=x_train.drop(columns={'gender','fever','cough','city'}).values

# also the test data
x_test_age=x_test.drop(columns=['gender','fever','cough','city']).values

x_train_age.shape
# Out:
# (80, 1)

# %%
x_train_transformed=np.concatenate((x_train_age,x_train_fever,x_train_gender_city,x_train_cough),axis=1)

# %%
x_train_transformed.shape
# Out:
# (80, 7)

# %% [markdown]
#  # **BY THE HELP OF COLUMN TRANSFORMER**

# %%
from sklearn.compose import ColumnTransformer # this is how to import ColumnTransformer

transformer = ColumnTransformer(transformers=[
('tnf1',SimpleImputer(),['fever']),
#help of SI we
#fill missing values by mean , median , mode .
('tnf2',OrdinalEncoder(categories=[['Mild','Strong']]), ['cough']), # by
#this process |
#we encode our data .
('tnf3',OneHotEncoder(sparse_output=False,drop='first'), ['gender','city'])
],remainder='passthrough') # remainder = passthrough == >
#the columns remain same.
# it means rest all the

# in a 'fever'column by the

# %%
transformer.fit_transform(x_train).shape
# Out:
# (80, 7)

# %%
transformer.transform(x_test).shape
# Out:
# (20, 7)

# %% [markdown]
# # TIPS DATASET

# %%
import seaborn as sns

# %%
df=sns.load_dataset('tips')
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop(columns=['total_bill']),df['total_bill'],test_size=0.2)

# %%
from sklearn.compose import ColumnTransformer

# %%
transformer=ColumnTransformer(transformers=[('tnf1',OrdinalEncoder(categories=[['Thur','Fri','Sat','Sun'],['Lunch','Dinner']]),['day','time']),
                                           ('tnf2',OneHotEncoder(sparse_output=False,drop='first'),['sex','smoker'])]
                              ,remainder='passthrough')

# %%
transformer.fit_transform(x_train).shape
# Out:
# (195, 6)

# %%
transformer.fit_transform(x_test).shape
# Out:
# (49, 6)

# %% [markdown]
# # Model dataset

# %%
df=pd.read_csv("/content/toyota - toyota.csv")
df.head(5)
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0  GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
# 1  GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0
# 2  GT86  2015  13998       Manual    27469   Petrol  265  36.2         2.0
# 3  GT86  2017  18998       Manual    14736   Petrol  150  36.2         2.0
# 4  GT86  2017  17498       Manual    36284   Petrol  145  36.2         2.0

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop(columns='price'),df['price'],test_size=0.2)

# %%
from sklearn.compose import ColumnTransformer

# %%
transformer=ColumnTransformer(transformers=[('tnf1',OrdinalEncoder(categories=[['Manual', 'Automatic', 'Semi-Auto', 'Other'],['Petrol', 'Hybrid', 'Diesel','Other']]),['transmission','fuelType'])],remainder='passthrough')

# %%
transformer.fit_transform(x_train).shape
# Out:
# (5390, 8)
